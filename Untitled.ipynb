# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    # Otentikasi dan akses menggunakan kunci:
    auth = tweepy.OAuthHandler("rNDxOfxKXUkbOqixQJwpLBfsX",
    "hqvmJGAJnvMkXjFhgeRtJud32fr4SvNddpbzxHXlkZcpA30Tcu")
    auth.set_access_token("1569886796179456006-qgIFEhKzpSK6aOCdJSfxsNtQUqd5g3",
    "w4fMMrp3U1kqgQuoXYRWwHxw9PhmDnAXhR3VGUAhJA6aP")
    # Kembalikan akses ke API:
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# buat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %%
tweets = extractor.user_timeline(screen_name="VICE_ID", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))


print("5 tweet teratas:\n")
for tweet in tweets[:5]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 200.
#
# 5 tweet teratas:
#
# Nama-nama seperti Tulus, The Jansen, Danilla, hingga Perunggu yang masuk daftar ini, membuktikan sepanjang 2022 ban… https://t.co/3zCuUK9oIF
#
# Menurut lelaki yang nge-admin akun OnlyFans, para model bisa saja mengelola akun mereka sendiri, tapi mereka mungki… https://t.co/qRLYGGNAfi
#
# Terima kasih akun-akun yang rajin nge-share foto kucing dan anjing menggemaskan. Kalian membantu banyak orang tetap… https://t.co/h8tnhQQe3t
#
# Kisah inspiratif kali ini hadir dari nelayan Tehoru, di Seram, Maluku Tengah. Mereka spesialis penangkap tuna secar… https://t.co/DwKXLRWl5r
#
# Akibat pandemi, para remaja bosan Indonesia mengadakan balapan lari liar di jalanan. Balapan ini menjadi cukup mere… https://t.co/W12DtW8f5r

# %%
# Kita dapat membuat kerangka data sebagai berikut:
dataset = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# Kami membuat tampilan kerangka data:
display(dataset.head(10))
# Out:
#                                               Tweets
# 0  Nama-nama seperti Tulus, The Jansen, Danilla, ...
# 1  Menurut lelaki yang nge-admin akun OnlyFans, p...
# 2  Terima kasih akun-akun yang rajin nge-share fo...
# 3  Kisah inspiratif kali ini hadir dari nelayan T...
# 4  Akibat pandemi, para remaja bosan Indonesia me...
# 5  Pameran di Kyoto, Jepang, menyuguhkan proyek f...
# 6  Perilaku seks sampai mati ternyata merupakan h...
# 7  Tak jarang orang terkejut melihat sifat asli p...
# 8  Mamalia selain manusia, berdasar kesimpulan ri...
# 9  Aku bertanya ke peneliti dan psikolog, kenapa ...

# %%
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1608801023598161920
# 2022-12-30 12:23:48+00:00
# Twitter for iPhone
# 42
# 7
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/3zCuUK9oIF', 'expanded_url': 'https://twitter.com/i/web/status/1608801023598161920', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
dataset['len'] = np.array([len(tweet.text) for tweet in tweets])
dataset['ID']  = np.array([tweet.id for tweet in tweets])
dataset['Created'] = np.array([tweet.created_at for tweet in tweets])
dataset['Source'] = np.array([tweet.source for tweet in tweets])
dataset['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
dataset['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

# %%
dataset.head()
# Out:
#                                               Tweets  len  \
# 0  Nama-nama seperti Tulus, The Jansen, Danilla, ...  140
# 1  Menurut lelaki yang nge-admin akun OnlyFans, p...  140
# 2  Terima kasih akun-akun yang rajin nge-share fo...  140
# 3  Kisah inspiratif kali ini hadir dari nelayan T...  140
# 4  Akibat pandemi, para remaja bosan Indonesia me...  140
#
#                     ID                   Created              Source  Likes  \
# 0  1608801023598161920 2022-12-30 12:23:48+00:00  Twitter for iPhone     42
# 1  1608779998713765891 2022-12-30 11:00:16+00:00          SocialFlow      9
# 2  1608764878487015424 2022-12-30 10:00:11+00:00          SocialFlow     48
# 3  1608749755693154305 2022-12-30 09:00:05+00:00          SocialFlow    103
# 4  1608736877229514754 2022-12-30 08:08:55+00:00          SocialFlow     15
#
#    RTs
# 0    7
# 1    3
# 2   11
# 3   21
# 4    2

# %%
# extract rata-rata:
media = np.mean(dataset['len'])

print("Jumlah rata-rata karakter di tweet: {}".format(media))
# Out:
# Jumlah rata-rata karakter di tweet: 127.315

# %%
# Kami mengekstrak tweet dengan FAV paling banyak dan dengan RT terbanyak:

fav_max = np.max(dataset['Likes'])
rt_max  = np.max(dataset['RTs'])

fav = dataset[dataset.Likes == fav_max].index[0]
rt  = dataset[dataset.RTs == rt_max].index[0]

# Max FAVs:
print("Tweet yang paling banyak disukai adalah: \n{}".format(dataset['Tweets'][fav]))
print("Jumlah suka: {}".format(fav_max))
print("{} Characters.\n".format(dataset['len'][fav]))
# Out:
# Tweet yang paling banyak disukai adalah:
# Apakah privasi pegawai warung makan, burjo, atau toko kelontong yang buka 24 jam terganggu? Ternyata, ada trik-trik… https://t.co/J1SNa7zQep
# Jumlah suka: 8510
# 140 Characters.

# %%
# Max RTs:
print("Tweet dengan retweet terbanyak adalah: \n{}".format(dataset['Tweets'][rt]))
print("Jumlah retweet: {}".format(rt_max))
print("{} Characters.\n".format(dataset['len'][rt]))
# Out:
# Tweet dengan retweet terbanyak adalah:
# Apakah privasi pegawai warung makan, burjo, atau toko kelontong yang buka 24 jam terganggu? Ternyata, ada trik-trik… https://t.co/J1SNa7zQep
# Jumlah retweet: 1197
# 140 Characters.

# %%
tlen = pd.Series(data=dataset['len'].values, index=dataset['Created'])
tfav = pd.Series(data=dataset['Likes'].values, index=dataset['Created'])
tret = pd.Series(data=dataset['RTs'].values, index=dataset['Created'])

# %%
tlen.plot(figsize=(16,4), color='r');

# %%
tfav.plot(figsize=(16,4), label="Likes", legend=True)
tret.plot(figsize=(16,4), label="Retweets", legend=True);

# %%
sources = []
for source in dataset['Source']:
    if source not in sources:
        sources.append(source)

# pembuatan:
print("Sumber pembuatan konten:")
for source in sources:
    print("* {}".format(source))
# Out:
# Sumber pembuatan konten:
# * Twitter for iPhone
# * SocialFlow
# * Twitter Web App

# %%
percent = np.zeros(len(sources))

for source in dataset['Source']:
    for index in range(len(sources)):
        if source == sources[index]:
            percent[index] += 1
            pass

percent /= 100

# Pie chart:
pie_chart = pd.Series(percent, index=sources, name='Sources')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6));

# %%
dataset.to_csv('dataset_USSFeeds.csv',sep=';')
